# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, average_precision_score

# %%
# 1. Load the dataset
data = pd.read_csv("merged_data.csv")

# 2. Select features and target variable
list_bp = ['avg_dbp', 'avg_diff', 'avg_sbp', 'max_sbp']
list_ed = ['age', 'sex', 'language', 'insurance_type', 'primary_care', 'ed_name',
           'bpa_response', 'htn_on_pl', 'htn_on_pmh', 'hld_on_pl', 'hld_on_pmh',
           'family_dm', 'tobacco_user', 'htn_meds', 'statin_meds', 'disposition',
           'detailed_race', 'weight', 'bmi', 'hba1c', 'height', 'sbp_1st', 'dbp_1st', 'poct_gluc']
list_lab = ['max_value_GLUCOSE', 'avg_value_GLUCOSE', 'max_value_CREATININE',
            'min_value_CREATININE', 'min_value_GLUCOSE', 'avg_value_CREATININE',
            'avg_value_HEMOGLOBIN A1C', 'max_value_HEMOGLOBIN A1C', 'min_value_HEMOGLOBIN A1C',
            'min_value_GLUCOSE, POC', 'avg_value_GLUCOSE, POC', 'max_value_GLUCOSE, POC']
list_geo = ['total_pop', 'households', 'housing_units', 'p_children', 'p_elderly',
            'p_adults', 'p_female', 'mdn_age', 'p_nhwhite', 'p_nhblack', 'p_hispanic',
            'p_nhasian', 'p_other', 'p_moved', 'p_longcommute', 'p_marriednone', 'p_marriedkids',
            'p_singlenone', 'p_malekids', 'p_femalekids', 'p_cohabitkids', 'hh_mdnincome']
list_visit = ['visit_type']

# Define features and target
X_all = data[list_bp + list_ed + list_lab + list_geo + list_visit]
y = data['pcp_followup'].map({'Yes': 1, 'No': 0}).astype(int)

# %%
# Data preprocessing
numeric_cols = X_all.select_dtypes(include=['number']).columns
categorical_cols = X_all.select_dtypes(exclude=['number']).columns

numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_cols),
    ('cat', categorical_transformer, categorical_cols)
])

X_preprocessed = preprocessor.fit_transform(X_all)
if hasattr(X_preprocessed, "toarray"):
    X_preprocessed = X_preprocessed.toarray()

# Split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

# %%
# Build Neural Network Model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),  # First hidden layer
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu'),  # Second hidden layer
    BatchNormalization(),
    Dropout(0.3),

    Dense(32, activation='relu'),  # Third hidden layer
    BatchNormalization(),
    Dropout(0.2),

    Dense(1, activation='sigmoid')  # Output layer (binary classification)
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=1)

# Evaluate the model
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Compute accuracy & classification metrics
accuracy = accuracy_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred_prob)
auc_pr = average_precision_score(y_test, y_pred_prob)

print(f"Test Accuracy: {accuracy:.2f}")
print(f"AUC-ROC: {auc_roc:.2f}")
print(f"AUC-PR: {auc_pr:.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.5890 - loss: 0.7416 - val_accuracy: 0.8039 - val_loss: 0.6786
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5335 - loss: 0.7985 - val_accuracy: 0.8039 - val_loss: 0.6619
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5011 - loss: 0.8047 - val_accuracy: 0.8039 - val_loss: 0.6468
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5627 - loss: 0.7446 - val_accuracy: 0.8039 - val_loss: 0.6324
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5598 - loss: 0.8018 - val_accuracy: 0.8039 - val_loss: 0.6200
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6055 - loss: 0.7615 - val_accuracy: 0.8039 - val_loss: 0.6084
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5382 - loss: 0.7555 - val_accuracy: 0.8039 - val_loss: 0.5976
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5930 - loss: 0.6932 - val_accuracy: 0.8039 - val_loss: 0.5872
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5882 - loss: 0.6848 - val_accuracy: 0.8039 - val_loss: 0.5779
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5575 - loss: 0.7085 - val_accuracy: 0.8039 - val_loss: 0.5703
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6135 - loss: 0.6800 - val_accuracy: 0.8039 - val_loss: 0.5635
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6428 - loss: 0.7057 - val_accuracy: 0.8039 - val_loss: 0.5579
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6463 - loss: 0.6636 - val_accuracy: 0.8039 - val_loss: 0.5518
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6994 - loss: 0.6221 - val_accuracy: 0.8039 - val_loss: 0.5456
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6731 - loss: 0.6234 - val_accuracy: 0.8039 - val_loss: 0.5411
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6639 - loss: 0.6491 - val_accuracy: 0.8039 - val_loss: 0.5368
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7011 - loss: 0.6242 - val_accuracy: 0.8039 - val_loss: 0.5326
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6730 - loss: 0.6280 - val_accuracy: 0.8039 - val_loss: 0.5289
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6860 - loss: 0.6372 - val_accuracy: 0.8039 - val_loss: 0.5248
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6759 - loss: 0.6598 - val_accuracy: 0.8039 - val_loss: 0.5217
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7429 - loss: 0.6075 - val_accuracy: 0.8039 - val_loss: 0.5188
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7515 - loss: 0.5523 - val_accuracy: 0.8039 - val_loss: 0.5170
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7220 - loss: 0.5765 - val_accuracy: 0.8039 - val_loss: 0.5153
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7442 - loss: 0.5768 - val_accuracy: 0.8039 - val_loss: 0.5134
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6964 - loss: 0.6513 - val_accuracy: 0.8039 - val_loss: 0.5114
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6235 - loss: 0.6960 - val_accuracy: 0.8039 - val_loss: 0.5091
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7077 - loss: 0.6180 - val_accuracy: 0.8039 - val_loss: 0.5068
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7421 - loss: 0.5645 - val_accuracy: 0.8039 - val_loss: 0.5050
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7417 - loss: 0.5504 - val_accuracy: 0.8039 - val_loss: 0.5030
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7674 - loss: 0.5841 - val_accuracy: 0.8039 - val_loss: 0.5018
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7068 - loss: 0.5682 - val_accuracy: 0.8039 - val_loss: 0.5009
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7421 - loss: 0.5796 - val_accuracy: 0.8039 - val_loss: 0.4998
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7523 - loss: 0.5682 - val_accuracy: 0.8039 - val_loss: 0.4992
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6891 - loss: 0.6279 - val_accuracy: 0.8039 - val_loss: 0.4991
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7827 - loss: 0.5678 - val_accuracy: 0.8039 - val_loss: 0.4983
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7034 - loss: 0.6159 - val_accuracy: 0.8039 - val_loss: 0.4980
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7331 - loss: 0.5650 - val_accuracy: 0.8039 - val_loss: 0.4977
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7409 - loss: 0.5839 - val_accuracy: 0.8039 - val_loss: 0.4968
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7410 - loss: 0.5509 - val_accuracy: 0.8039 - val_loss: 0.4965
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7900 - loss: 0.5153 - val_accuracy: 0.8039 - val_loss: 0.4963
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7965 - loss: 0.4740 - val_accuracy: 0.8039 - val_loss: 0.4957
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7579 - loss: 0.5491 - val_accuracy: 0.8039 - val_loss: 0.4955
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7511 - loss: 0.5905 - val_accuracy: 0.8039 - val_loss: 0.4955
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7789 - loss: 0.5370 - val_accuracy: 0.8039 - val_loss: 0.4953
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7510 - loss: 0.5170 - val_accuracy: 0.8039 - val_loss: 0.4952
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7867 - loss: 0.5315 - val_accuracy: 0.8039 - val_loss: 0.4954
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7881 - loss: 0.5320 - val_accuracy: 0.8039 - val_loss: 0.4955
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7513 - loss: 0.5467 - val_accuracy: 0.8039 - val_loss: 0.4952
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7538 - loss: 0.5421 - val_accuracy: 0.8039 - val_loss: 0.4950
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7612 - loss: 0.5559 - val_accuracy: 0.8039 - val_loss: 0.4949
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Test Accuracy: 0.80
# AUC-ROC: 0.50
# AUC-PR: 0.80
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.80      1.00      0.89        41
#
#     accuracy                           0.80        51
#    macro avg       0.40      0.50      0.45        51
# weighted avg       0.65      0.80      0.72        51
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
