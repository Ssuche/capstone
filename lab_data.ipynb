# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

path = 'data/'

# %%
# import the redcap data
# data\Deidentified REDCap Survey Data 2024.08.26.csv
redcap = pd.read_csv(path + 'Deidentified REDCap Survey Data 2024.08.26.csv')
redcap['visit_date'] = pd.to_datetime(redcap['visit_date']).dt.strftime('%Y-%m-%d')
temp = redcap.copy()
temp['visit_date'] = pd.to_datetime(temp['visit_date'])
temp = temp[['encrypt_mrn', 'ed_screened', 'visit_date', 'new_diagnosis', 'pcp_followup']]
temp = temp.drop_duplicates(subset='encrypt_mrn', keep='first')

# %%
# import the lab data
# data\Historical Lab Data File 2024.08.23.csv
lab = pd.read_csv(path + 'Historical Lab Data File 2024.08.23.csv')
lab['lab_date'] = pd.to_datetime(lab['lab_date']).dt.strftime('%Y-%m-%d')
lab = lab.rename(columns={'lab_date': 'visit_date'})

# %%
lab_group = lab.groupby(['encrypt_mrn', 'visit_date', 'lab_name']).agg(
    avg_value=('lab_value', 'mean'),
    max_value=('lab_value', 'max'),
    min_value=('lab_value', 'min')
).reset_index()

# %%
lab_table = lab_group.pivot_table(
    index=['encrypt_mrn', 'visit_date'], 
    columns='lab_name', 
    values=['avg_value', 'max_value', 'min_value']).reset_index()
lab_table.columns = [
    col[0] if col[0] in ['encrypt_mrn', 'visit_date'] else '_'.join(col).strip() 
    for col in lab_table.columns]

# %%
temp['visit_date'] = pd.to_datetime(temp['visit_date'], errors='coerce')
lab_table['visit_date'] = pd.to_datetime(lab_table['visit_date'], errors='coerce')
merged = pd.merge(temp, lab_table, on=['encrypt_mrn','visit_date'], how='left')
merged.head()
# Out:
#    encrypt_mrn      ed_screened visit_date new_diagnosis pcp_followup  \
# 0      2303579     NYU Brooklyn 2023-01-10           Yes          Yes
# 1      2114620     NYU Brooklyn 2022-01-11            No           No
# 2      2116246     NYU Brooklyn 2022-01-12            No          Yes
# 3      2183529     NYU Brooklyn 2023-01-12            No          Yes
# 4      2117042  NYU Long Island 2022-01-13           Yes          Yes
#
#    avg_value_CHOLESTEROL, TOTAL  avg_value_CREATININE  avg_value_GLUCOSE  \
# 0                         268.0                  0.74              305.0
# 1                           NaN                  0.70              386.0
# 2                           NaN                  0.74              401.0
# 3                           NaN                  0.64              214.0
# 4                           NaN                   NaN                NaN
#
#    avg_value_GLUCOSE, POC  avg_value_HDL CHOLESTEROL  ...  \
# 0              269.333333                       31.0  ...
# 1              324.000000                        NaN  ...
# 2              300.666667                        NaN  ...
# 3              228.000000                        NaN  ...
# 4              443.000000                        NaN  ...
#
#    max_value_HDL CHOLESTEROL  max_value_HEMOGLOBIN A1C  \
# 0                       31.0                       9.3
# 1                        NaN                      11.8
# 2                        NaN                      12.1
# 3                        NaN                       7.7
# 4                        NaN                       NaN
#
#    max_value_LDL CHOLESTEROL, CALCULATED  min_value_CHOLESTEROL, TOTAL  \
# 0                                  176.0                         268.0
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#    min_value_CREATININE  min_value_GLUCOSE  min_value_GLUCOSE, POC  \
# 0                  0.74              305.0                   230.0
# 1                  0.70              386.0                   220.0
# 2                  0.74              401.0                   260.0
# 3                  0.64              214.0                   228.0
# 4                   NaN                NaN                   443.0
#
#    min_value_HDL CHOLESTEROL  min_value_HEMOGLOBIN A1C  \
# 0                       31.0                       9.3
# 1                        NaN                      11.8
# 2                        NaN                      12.1
# 3                        NaN                       7.7
# 4                        NaN                       NaN
#
#    min_value_LDL CHOLESTEROL, CALCULATED
# 0                                  176.0
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 26 columns]

# %%
# save as lab_data.csv
merged.to_csv('processed_data/lab_data.csv', index=False)
